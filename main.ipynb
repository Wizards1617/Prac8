# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv('new.csv')
data.dropna()
data
# Out:
#      Unnamed: 0   Rank                                Name Platform    Year
# 0             0   9424                      Winning Post 5      PS2  2001.0  \
# 1             1  15694                    Prince of Stride      PSV  2015.0
# 2             2  15166         Cities in Motion Collection       PC  2011.0
# 3             3  12177                 Winning Post 7 2010      PS3  2010.0
# 4             4   9874  Ed, Edd n Eddy: The Mis-Edventures      GBA  2005.0
# ..          ...    ...                                 ...      ...     ...
# 548         548  12799                        Space Chimps       DS  2008.0
# 549         549  14424          Codename: Panzers Cold War       PC  2009.0
# 550         550   7549                    MLB 10: The Show      PSP  2010.0
# 551         551   2207   The Witcher 2: Assassins of Kings     X360  2012.0
# 552         552  15733                Super Speed Machines       DS  2009.0
#
#           Genre                        Publisher  NA_Sales  EU_Sales
# 0        Sports                       Tecmo Koei      0.00      0.00  \
# 1     Adventure                   Kadokawa Games      0.00      0.00
# 2    Simulation                          Unknown      0.00      0.02
# 3        Sports                       Tecmo Koei      0.00      0.00
# 4      Platform                     Midway Games      0.08      0.03
# ..          ...                              ...       ...       ...
# 548    Platform              Brash Entertainment      0.05      0.00
# 549    Strategy                            Atari      0.00      0.02
# 550      Sports      Sony Computer Entertainment      0.19      0.00
# 551      Action               Namco Bandai Games      0.48      0.36
# 552      Racing  Midas Interactive Entertainment      0.02      0.00
#
#      JP_Sales  Other_Sales  Global_Sales
# 0        0.13         0.00          0.13
# 1        0.02         0.00          0.02
# 2        0.00         0.00          0.02
# 3        0.07         0.00          0.07
# 4        0.00         0.00          0.12
# ..        ...          ...           ...
# 548      0.00         0.00          0.06
# 549      0.00         0.01          0.03
# 550      0.00         0.02          0.20
# 551      0.02         0.08          0.94
# 552      0.00         0.00          0.02
#
# [553 rows x 12 columns]

# %%
#категориальная целевая переменная
features = data.drop('Genre', axis=1) 
target = data['Genre']
label_encoder = LabelEncoder()
for column in features.columns:
    if features[column].dtype == 'object':
        features[column] = label_encoder.fit_transform(features[column])

# %%
kfold = KFold(n_splits=5, shuffle=True)

# %%
for train_index, test_index in kfold.split(features):
    X_train, X_test = features.iloc[train_index], features.iloc[test_index]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]

    print("\n")

    model_dt = DecisionTreeClassifier()
    model_dt.fit(X_train, y_train)
    y_pred_dt = model_dt.predict(X_test)
    accuracy_dt = accuracy_score(y_test, y_pred_dt)
    print(f"Decision Tree Accuracy: {accuracy_dt}")
    
    model_svm = SVC()
    model_svm.fit(X_train, y_train)
    y_pred_svm = model_svm.predict(X_test)
    accuracy_svm = accuracy_score(y_test, y_pred_svm)
    print(f"SVM Accuracy: {accuracy_svm}")

    model_knn = KNeighborsClassifier()
    model_knn.fit(X_train, y_train)
    y_pred_knn = model_knn.predict(X_test)
    accuracy_knn = accuracy_score(y_test, y_pred_knn)
    print(f"K-Nearest Neighbors Accuracy: {accuracy_knn}")

    model_rf = RandomForestClassifier()
    model_rf.fit(X_train, y_train)
    y_pred_rf = model_rf.predict(X_test)
    accuracy_rf = accuracy_score(y_test, y_pred_rf)
    print(f"Random Forest Accuracy: {accuracy_rf}")

    print("Набор предсказаний дерева решений: ",y_pred_dt)
# Out:
# Decision Tree Accuracy: 0.15315315315315314
# SVM Accuracy: 0.26126126126126126
# K-Nearest Neighbors Accuracy: 0.1981981981981982
# Random Forest Accuracy: 0.1891891891891892
# Набор предсказаний дерева решений:  ['Sports' 'Simulation' 'Action' 'Simulation' 'Fighting' 'Sports'
#  'Fighting' 'Racing' 'Racing' 'Action' 'Role-Playing' 'Action' 'Racing'
#  'Shooter' 'Sports' 'Simulation' 'Role-Playing' 'Role-Playing' 'Puzzle'
#  'Simulation' 'Puzzle' 'Role-Playing' 'Action' 'Action' 'Action' 'Racing'
#  'Action' 'Simulation' 'Action' 'Puzzle' 'Sports' 'Sports' 'Sports'
#  'Role-Playing' 'Misc' 'Misc' 'Racing' 'Misc' 'Role-Playing' 'Racing'
#  'Sports' 'Shooter' 'Shooter' 'Action' 'Action' 'Action' 'Shooter'
#  'Puzzle' 'Platform' 'Simulation' 'Misc' 'Platform' 'Sports' 'Misc'
#  'Sports' 'Racing' 'Action' 'Simulation' 'Racing' 'Sports' 'Action'
#  'Adventure' 'Action' 'Sports' 'Racing' 'Racing' 'Role-Playing' 'Racing'
#  'Role-Playing' 'Strategy' 'Platform' 'Sports' 'Racing' 'Strategy'
#  'Sports' 'Sports' 'Action' 'Misc' 'Simulation' 'Simulation'
#  'Role-Playing' 'Platform' 'Platform' 'Misc' 'Misc' 'Fighting' 'Misc'
#  'Misc' 'Action' 'Sports' 'Racing' 'Action' 'Strategy' 'Racing'
#  'Role-Playing' 'Role-Playing' 'Fighting' 'Action' 'Racing' 'Puzzle'
#  'Shooter' 'Fighting' 'Action' 'Simulation' 'Sports' 'Adventure' 'Action'
#  'Action' 'Fighting' 'Puzzle' 'Puzzle']
#
#
# Decision Tree Accuracy: 0.21621621621621623
# SVM Accuracy: 0.2072072072072072
# K-Nearest Neighbors Accuracy: 0.0990990990990991
# Random Forest Accuracy: 0.2702702702702703
# Набор предсказаний дерева решений:  ['Fighting' 'Racing' 'Sports' 'Sports' 'Adventure' 'Misc' 'Sports' 'Misc'
#  'Action' 'Action' 'Role-Playing' 'Fighting' 'Fighting' 'Misc' 'Action'
#  'Action' 'Action' 'Action' 'Misc' 'Action' 'Action' 'Sports' 'Sports'
#  'Simulation' 'Role-Playing' 'Role-Playing' 'Role-Playing' 'Platform'
#  'Sports' 'Sports' 'Action' 'Puzzle' 'Adventure' 'Adventure' 'Shooter'
#  'Role-Playing' 'Sports' 'Strategy' 'Action' 'Racing' 'Shooter' 'Racing'
#  'Adventure' 'Fighting' 'Role-Playing' 'Action' 'Sports' 'Misc' 'Sports'
#  'Sports' 'Shooter' 'Misc' 'Misc' 'Sports' 'Simulation' 'Action' 'Sports'
#  'Racing' 'Role-Playing' 'Racing' 'Puzzle' 'Racing' 'Adventure' 'Sports'
#  'Strategy' 'Role-Playing' 'Action' 'Action' 'Role-Playing' 'Action'
#  'Racing' 'Adventure' 'Simulation' 'Shooter' 'Role-Playing' 'Sports'
#  'Sports' 'Sports' 'Puzzle' 'Action' 'Fighting' 'Action' 'Misc' 'Puzzle'
#  'Action' 'Action' 'Strategy' 'Simulation' 'Shooter' 'Sports' 'Sports'
#  'Action' 'Strategy' 'Shooter' 'Adventure' 'Adventure' 'Action' 'Shooter'
#  'Adventure' 'Simulation' 'Role-Playing' 'Adventure' 'Puzzle' 'Racing'
#  'Sports' 'Fighting' 'Action' 'Fighting' 'Shooter' 'Sports' 'Racing']
#
#
# Decision Tree Accuracy: 0.25225225225225223
# SVM Accuracy: 0.22522522522522523
# K-Nearest Neighbors Accuracy: 0.12612612612612611
# Random Forest Accuracy: 0.27927927927927926
# Набор предсказаний дерева решений:  ['Sports' 'Role-Playing' 'Action' 'Sports' 'Action' 'Sports' 'Sports'
#  'Misc' 'Misc' 'Adventure' 'Role-Playing' 'Role-Playing' 'Action'
#  'Fighting' 'Sports' 'Action' 'Sports' 'Sports' 'Role-Playing' 'Sports'
#  'Misc' 'Shooter' 'Adventure' 'Puzzle' 'Fighting' 'Sports' 'Action'
#  'Shooter' 'Misc' 'Role-Playing' 'Sports' 'Action' 'Role-Playing'
#  'Shooter' 'Role-Playing' 'Misc' 'Fighting' 'Role-Playing' 'Role-Playing'
#  'Racing' 'Action' 'Fighting' 'Sports' 'Fighting' 'Action' 'Action'
#  'Role-Playing' 'Sports' 'Platform' 'Adventure' 'Role-Playing' 'Adventure'
#  'Role-Playing' 'Racing' 'Platform' 'Adventure' 'Misc' 'Action' 'Fighting'
#  'Misc' 'Action' 'Action' 'Role-Playing' 'Misc' 'Adventure' 'Role-Playing'
#  'Racing' 'Action' 'Action' 'Action' 'Misc' 'Action' 'Action' 'Sports'
#  'Misc' 'Simulation' 'Fighting' 'Puzzle' 'Misc' 'Sports' 'Action' 'Action'
#  'Shooter' 'Action' 'Action' 'Strategy' 'Sports' 'Action' 'Sports'
#  'Racing' 'Misc' 'Puzzle' 'Action' 'Simulation' 'Action' 'Action' 'Action'
#  'Shooter' 'Shooter' 'Puzzle' 'Racing' 'Action' 'Action' 'Action'
#  'Platform' 'Puzzle' 'Role-Playing' 'Puzzle' 'Platform' 'Action' 'Action']
#
#
# Decision Tree Accuracy: 0.14545454545454545
# SVM Accuracy: 0.2
# K-Nearest Neighbors Accuracy: 0.09090909090909091
# Random Forest Accuracy: 0.16363636363636364
# Набор предсказаний дерева решений:  ['Racing' 'Role-Playing' 'Racing' 'Adventure' 'Simulation' 'Action'
#  'Racing' 'Puzzle' 'Shooter' 'Action' 'Misc' 'Action' 'Shooter'
#  'Role-Playing' 'Misc' 'Racing' 'Action' 'Role-Playing' 'Action'
#  'Role-Playing' 'Sports' 'Role-Playing' 'Sports' 'Sports' 'Action'
#  'Role-Playing' 'Action' 'Racing' 'Action' 'Role-Playing' 'Misc'
#  'Strategy' 'Action' 'Fighting' 'Action' 'Role-Playing' 'Action' 'Sports'
#  'Action' 'Action' 'Sports' 'Action' 'Platform' 'Fighting' 'Role-Playing'
#  'Platform' 'Misc' 'Platform' 'Action' 'Adventure' 'Action' 'Racing'
#  'Fighting' 'Adventure' 'Strategy' 'Strategy' 'Action' 'Sports' 'Action'
#  'Sports' 'Action' 'Adventure' 'Action' 'Racing' 'Racing' 'Racing'
#  'Racing' 'Shooter' 'Racing' 'Role-Playing' 'Action' 'Strategy' 'Action'
#  'Misc' 'Sports' 'Strategy' 'Sports' 'Action' 'Strategy' 'Puzzle' 'Racing'
#  'Misc' 'Adventure' 'Sports' 'Action' 'Action' 'Action' 'Sports' 'Misc'
#  'Sports' 'Role-Playing' 'Sports' 'Strategy' 'Platform' 'Adventure'
#  'Racing' 'Action' 'Action' 'Adventure' 'Misc' 'Adventure' 'Platform'
#  'Role-Playing' 'Puzzle' 'Platform' 'Platform' 'Sports' 'Shooter'
#  'Simulation' 'Platform']
#
#
# Decision Tree Accuracy: 0.2
# SVM Accuracy: 0.20909090909090908
# K-Nearest Neighbors Accuracy: 0.14545454545454545
# Random Forest Accuracy: 0.3
# Набор предсказаний дерева решений:  ['Platform' 'Sports' 'Misc' 'Misc' 'Sports' 'Shooter' 'Platform'
#  'Strategy' 'Racing' 'Platform' 'Simulation' 'Puzzle' 'Role-Playing'
#  'Adventure' 'Racing' 'Platform' 'Racing' 'Platform' 'Action' 'Misc'
#  'Racing' 'Misc' 'Sports' 'Puzzle' 'Simulation' 'Racing' 'Puzzle' 'Misc'
#  'Sports' 'Action' 'Action' 'Role-Playing' 'Sports' 'Misc' 'Adventure'
#  'Racing' 'Role-Playing' 'Action' 'Action' 'Misc' 'Puzzle' 'Sports'
#  'Puzzle' 'Sports' 'Platform' 'Simulation' 'Strategy' 'Action' 'Platform'
#  'Action' 'Shooter' 'Misc' 'Sports' 'Racing' 'Sports' 'Sports' 'Misc'
#  'Strategy' 'Racing' 'Action' 'Puzzle' 'Action' 'Platform' 'Fighting'
#  'Adventure' 'Puzzle' 'Adventure' 'Action' 'Action' 'Role-Playing'
#  'Action' 'Action' 'Fighting' 'Strategy' 'Action' 'Shooter' 'Sports'
#  'Simulation' 'Adventure' 'Sports' 'Misc' 'Racing' 'Shooter' 'Sports'
#  'Role-Playing' 'Action' 'Sports' 'Role-Playing' 'Action' 'Action'
#  'Racing' 'Misc' 'Sports' 'Adventure' 'Action' 'Role-Playing' 'Sports'
#  'Fighting' 'Sports' 'Platform' 'Shooter' 'Action' 'Adventure' 'Strategy'
#  'Action' 'Racing' 'Action' 'Sports' 'Action' 'Sports']

# %%
print("Набор предсказаний опорных векторов: ",y_pred_svm)
# Out:
# Набор предсказаний опорных векторов:  ['Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action'
#  'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action'
#  'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action'
#  'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action'
#  'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action'
#  'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action'
#  'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action'
#  'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action'
#  'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action'
#  'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action'
#  'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action'
#  'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action'
#  'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action' 'Action'
#  'Action' 'Action' 'Action' 'Action' 'Action' 'Action']

# %%
print("Набор предсказаний к-ближайших соседей: ",y_pred_knn)
# Out:
# Набор предсказаний к-ближайших соседей:  ['Adventure' 'Action' 'Action' 'Puzzle' 'Sports' 'Action' 'Action'
#  'Action' 'Adventure' 'Action' 'Sports' 'Action' 'Action' 'Action'
#  'Role-Playing' 'Racing' 'Action' 'Misc' 'Action' 'Misc' 'Adventure'
#  'Misc' 'Action' 'Platform' 'Misc' 'Fighting' 'Misc' 'Adventure'
#  'Adventure' 'Role-Playing' 'Action' 'Action' 'Misc' 'Action' 'Adventure'
#  'Action' 'Action' 'Platform' 'Action' 'Action' 'Action' 'Adventure'
#  'Misc' 'Platform' 'Action' 'Action' 'Misc' 'Action' 'Adventure' 'Action'
#  'Action' 'Sports' 'Role-Playing' 'Action' 'Action' 'Sports' 'Action'
#  'Racing' 'Action' 'Action' 'Racing' 'Action' 'Role-Playing' 'Action'
#  'Action' 'Action' 'Action' 'Shooter' 'Role-Playing' 'Sports' 'Action'
#  'Action' 'Action' 'Platform' 'Action' 'Action' 'Action' 'Action'
#  'Adventure' 'Puzzle' 'Racing' 'Action' 'Adventure' 'Puzzle' 'Puzzle'
#  'Adventure' 'Action' 'Action' 'Misc' 'Action' 'Action' 'Action'
#  'Adventure' 'Action' 'Action' 'Racing' 'Sports' 'Action' 'Action' 'Misc'
#  'Sports' 'Action' 'Action' 'Action' 'Adventure' 'Action' 'Action'
#  'Action' 'Action' 'Sports']

# %%
print("Набор предсказаний рандомного дерева: ",y_pred_rf)
# Out:
# Набор предсказаний рандомного дерева:  ['Puzzle' 'Racing' 'Misc' 'Action' 'Sports' 'Shooter' 'Platform'
#  'Strategy' 'Puzzle' 'Sports' 'Racing' 'Role-Playing' 'Sports'
#  'Role-Playing' 'Sports' 'Action' 'Racing' 'Action' 'Action' 'Misc'
#  'Platform' 'Platform' 'Role-Playing' 'Puzzle' 'Sports' 'Racing' 'Racing'
#  'Sports' 'Action' 'Action' 'Racing' 'Racing' 'Fighting' 'Action' 'Action'
#  'Racing' 'Role-Playing' 'Action' 'Role-Playing' 'Shooter' 'Sports'
#  'Action' 'Misc' 'Sports' 'Platform' 'Role-Playing' 'Action' 'Action'
#  'Action' 'Action' 'Racing' 'Action' 'Action' 'Action' 'Action' 'Sports'
#  'Action' 'Role-Playing' 'Racing' 'Role-Playing' 'Puzzle' 'Sports'
#  'Platform' 'Role-Playing' 'Action' 'Role-Playing' 'Action' 'Action'
#  'Action' 'Sports' 'Adventure' 'Action' 'Misc' 'Strategy' 'Action'
#  'Sports' 'Sports' 'Simulation' 'Adventure' 'Sports' 'Misc' 'Racing'
#  'Shooter' 'Action' 'Role-Playing' 'Action' 'Action' 'Action' 'Action'
#  'Platform' 'Racing' 'Misc' 'Racing' 'Role-Playing' 'Action' 'Sports'
#  'Sports' 'Action' 'Sports' 'Shooter' 'Racing' 'Action' 'Role-Playing'
#  'Strategy' 'Action' 'Racing' 'Action' 'Sports' 'Action' 'Action']

# %%
#числовая целевая переменная
features_1 = data[['NA_Sales']] 
target_1 = data['NA_Sales']

# %%
label_encoder = LabelEncoder()
for column in features_1.columns:
    if features_1[column].dtype == 'object':
        features_1[column] = label_encoder.fit_transform(features_1[column])

# %%
for train_index, test_index in kfold.split(features_1):
    X_train, X_test = features_1.iloc[train_index], features_1.iloc[test_index]
    y_train, y_test = target_1.iloc[train_index], target_1.iloc[test_index]

    # Линейная регрессия
    model_linear = LinearRegression()
    model_linear.fit(X_train, y_train)
    y_pred_linear = model_linear.predict(X_test)
    mse_linear = mean_squared_error(y_test, y_pred_linear)
    print(f'Linear Regression MSE: {mse_linear}')

    # Полиномиальная регрессия
    polynomial_features = PolynomialFeatures(degree=2)
    X_train_poly = polynomial_features.fit_transform(X_train)
    X_test_poly = polynomial_features.transform(X_test)

    model_poly = LinearRegression()
    model_poly.fit(X_train_poly, y_train)
    y_pred_poly = model_poly.predict(X_test_poly)
    mse_poly = mean_squared_error(y_test, y_pred_poly)
    print(f'Polynomial Regression MSE: {mse_poly}')

    # Гребневая регрессия
    model_ridge = Ridge()
    model_ridge.fit(X_train, y_train)
    y_pred_ridge = model_ridge.predict(X_test)
    mse_ridge = mean_squared_error(y_test, y_pred_ridge)
    print(f'Ridge Regression MSE: {mse_ridge}')

    # Лассо-регрессия
    model_lasso = Lasso()
    model_lasso.fit(X_train, y_train)
    y_pred_lasso = model_lasso.predict(X_test)
    mse_lasso = mean_squared_error(y_test, y_pred_lasso)
    print(f'Lasso Regression MSE: {mse_lasso}')

    print("\n")
    print("Набор предсказаний линейной регрессии: ",y_pred_linear)
# Out:
# Linear Regression MSE: 4.090828105100425e-32
# Polynomial Regression MSE: 1.1363194880527328e-30
# Ridge Regression MSE: 1.7865475480574106e-05
# Lasso Regression MSE: 0.6011227583493488
#
#
# Набор предсказаний линейной регрессии:  [ 2.10000000e-01  1.00000000e-01 -5.55111512e-17 -5.55111512e-17
#   3.20000000e-01  5.00000000e-02 -5.55111512e-17  2.90000000e-01
#   1.20000000e-01  4.00000000e-01 -5.55111512e-17  3.00000000e-02
#   4.50000000e-01  6.72000000e+00  8.00000000e-02  4.10000000e-01
#   5.10000000e-01  6.00000000e-02  2.30000000e-01 -5.55111512e-17
#   2.50000000e-01  2.00000000e-01  8.00000000e-02 -5.55111512e-17
#   3.00000000e-02  1.20000000e-01  2.00000000e-02  2.30000000e-01
#   2.00000000e-01 -5.55111512e-17  1.00000000e-02  4.00000000e-02
#   3.30000000e-01  1.48000000e+00  1.16000000e+00  2.00000000e-01
#   1.00000000e-02 -5.55111512e-17 -5.55111512e-17  3.00000000e-02
#   2.10000000e-01  6.70000000e-01  2.00000000e-02  1.60000000e-01
#   1.50000000e-01  3.00000000e-02  3.30000000e-01  6.00000000e-02
#  -5.55111512e-17  1.90000000e-01  2.00000000e-02  6.30000000e-01
#  -5.55111512e-17  1.96000000e+00 -5.55111512e-17  7.00000000e-02
#   1.40000000e-01  9.00000000e-02  2.60000000e-01  1.00000000e-02
#   9.80000000e-01 -5.55111512e-17  4.30000000e-01  1.00000000e-02
#   1.26000000e+00  3.10000000e-01  3.00000000e-02  2.50000000e-01
